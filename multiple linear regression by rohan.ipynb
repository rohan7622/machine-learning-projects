# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv("Salary_Data.csv")
df.head(3)
# Out:
#     Age  Experience  Salary
# 0  21.0         1.1   39343
# 1  21.5         1.3   46205
# 2  21.7         1.5   37731

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data = df)
plt.show()

# %%
sns.heatmap(data = df.corr(),annot = True)
plt.show()

# %%
x = df.iloc[:,:-1]
#x
y = df["Salary"]
#y

# %%
x.ndim # to chek dimention on dataset
# Out:
# 2

# %%
df.shape
# Out:
# (30, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 88.52101657216535

# %%
# y =m1x1+m2x2+c

# %%
lr.coef_
# Out:
# array([2567.51865301, 4882.14850701])

# %%
lr.intercept_
# Out:
# -20612.691921485282

# %%
# y_prd = 2567.51865301* Age + 4882.14850701 * Experience + -20612.691921485282

# %%
lr.predict(x_test)
# Out:
# array([118686.60525402,  67497.80208802, 101581.52273219,  74585.69879684,
#         54833.367916  ,  58044.6977654 ])
