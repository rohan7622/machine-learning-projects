# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Salary_Data.csv")
df.head(3)
# Out:
#     Age  Salary  Experience
# 0  21.0   39343         1.1
# 1  21.5   46205         1.3
# 2  21.7   37731         1.5

# %%
df.isnull().sum()
# Out:
# Age           0
# Salary        0
# Experience    0
# dtype: int64

# %%
sns.pairplot(data=df)
plt.show()

# %%
x=df.drop(columns="Salary")
y=df["Experience"]

# %%
y
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: Experience, dtype: float64

# %%
x
# Out:
#      Age  Experience
# 0   21.0         1.1
# 1   21.5         1.3
# 2   21.7         1.5
# 3   22.0         2.0
# 4   22.2         2.2
# 5   23.0         2.9
# 6   23.0         3.0
# 7   23.3         3.2
# 8   23.3         3.2
# 9   23.6         3.7
# 10  23.9         3.9
# 11  24.0         4.0
# 12  24.0         4.0
# 13  24.0         4.1
# 14  25.0         4.5
# 15  25.0         4.9
# 16  26.0         5.1
# 17  27.0         5.3
# 18  28.0         5.9
# 19  29.0         6.0
# 20  30.0         6.8
# 21  30.0         7.1
# 22  31.0         7.9
# 23  32.0         8.2
# 24  33.0         8.7
# 25  34.0         9.0
# 26  35.0         9.5
# 27  36.0         9.6
# 28  37.0        10.3
# 29  38.0        10.5

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test,y_test)*100
# Out:
# 98.4717068407257

# %%
knn.score(x_train,y_train)*100
# Out:
# 98.32592341621648

# %%
for i in range (1,20):
    knn1=KNeighborsRegressor(n_neighbors=i)
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 100.0 98.95153415223314
# 2 99.7302062353731 99.31387161432903
# 3 99.3536103913125 98.59519281835158
# 4 99.22857806137493 98.84360384437477
# 5 98.32592341621648 98.4717068407257
# 6 97.68855760724303 97.81997909921022
# 7 96.42576401125322 95.35364744654093
# 8 94.86591877325402 93.60416559592949
# 9 92.69476255398877 91.5658270183634
# 10 90.46174889102214 91.02081513080125
# 11 86.9933582406439 87.12609326690728
# 12 83.19613588403469 83.36374226927757
# 13 79.14446307049808 76.59034502725324
# 14 73.98517145861112 70.94865391291944
# 15 69.86024125279118 64.98987510921519
# 16 65.63923475822088 61.209654623014885
# 17 60.55341177304263 55.49931505424171
# 18 54.36708420020945 46.810916379709134
# 19 48.157036412738144 42.38810861709832
